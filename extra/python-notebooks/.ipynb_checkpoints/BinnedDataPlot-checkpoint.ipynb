# %% [markdown]
# # Binned data plot
#
# Here we illustrate how to bin the data to make plots that are not crowded.

# %%
# %pwd
# Out:
# '/home/akshit/python-notebooks'

# %%
# %ls
# Out:
# 2DPlots.ipynb         CurveFitting.ipynb  JMAKFit.tar          savefig.ipynb
# BinnedDataPlot.ipynb  JMAKFit/            LinearAlgebra.ipynb  twomil.csv

# %%
import numpy as np

# %%
d = np.loadtxt('twomil.csv', delimiter=',', usecols=(0,1))

# %%
d.shape
# Out:
# (2000000, 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(d[:,0], d[:,1], 'go')

# %%
dbin = d[::50000]

# %%
dbin.shape
# Out:
# (40, 2)

# %%
import matplotlib.pyplot as plt
plt.plot(dbin[:,0], dbin[:,1], 'bo')
plt.savefig('parabola.png', dpi=300)

# %%
# !ls -l parabola.png
